# %% [markdown]
# <a href="https://colab.research.google.com/github/Gustavo123435/Unit2_Data_preprocessing_Gustavo_Bacab/blob/main/Data_Gustavo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Homewoork EDA about Ramen Ratings by Gustavo Alejandro Bacab Ruiz

# %% [markdown]
# ## Context
# ### The Ramen Rater is a product review website for the hardcore ramen enthusiast (or "ramenphile"), with over 2500 reviews to date. This dataset is an export of "The Big List" (of reviews), converted to a CSV format.

# %% [markdown]
# ## Content
# Each record in the dataset is a single ramen product review. Review numbers are contiguous: more recently reviewed ramen varieties have higher numbers. Brand, Variety (the product name), Country, and Style (Cup? Bowl? Tray?) are pretty self-explanatory. Stars indicate the ramen quality, as assessed by the reviewer, on a 5-point scale; this is the most important column in the dataset!      Note that this dataset does not include the text of the reviews themselves. For that, you should browse through https://www.theramenrater.com/ instead!

# %% [markdown]
# ## Acknowledgements
# This dataset is republished as-is from the original BIG LIST on https://www.theramenrater.com/.

# %% [markdown]
# ## Inspiration
# * What ingredients or flavors are most commonly advertised on ramen package labels?
# * How do ramen ratings compare against ratings for other food products (like, say, wine)?
# * How is ramen manufacturing internationally distributed?

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
ramen = pd.read_csv('ramen-ratings.csv')
ramen
# Out:
#       Review #             Brand  \
# 0         2580         New Touch
# 1         2579          Just Way
# 2         2578            Nissin
# 3         2577           Wei Lih
# 4         2576    Ching's Secret
# 5         2575     Samyang Foods
# 6         2574           Acecook
# 7         2573       Ikeda Shoku
# 8         2572        Ripe'n'Dry
# 9         2571              KOKA
# 10        2570       Tao Kae Noi
# 11        2569          Yamachan
# 12        2568          Nongshim
# 13        2567            Nissin
# 14        2566            Nissin
# 15        2565              KOKA
# 16        2564              TRDP
# 17        2563          Yamachan
# 18        2562          Binh Tay
# 19        2561             Paldo
# 20        2560            Nissin
# 21        2559  Jackpot Teriyaki
# 22        2558              KOKA
# 23        2557          Yamachan
# 24        2556    Ching's Secret
# 25        2555     Samyang Foods
# 26        2554           Yum-Mie
# ...

# %%
ramen.head(15) # only 14 data
# Out:
#     Review #           Brand  \
# 0       2580       New Touch
# 1       2579        Just Way
# 2       2578          Nissin
# 3       2577         Wei Lih
# 4       2576  Ching's Secret
# 5       2575   Samyang Foods
# 6       2574         Acecook
# 7       2573     Ikeda Shoku
# 8       2572      Ripe'n'Dry
# 9       2571            KOKA
# 10      2570     Tao Kae Noi
# 11      2569        Yamachan
# 12      2568        Nongshim
# 13      2567          Nissin
# 14      2566          Nissin
#
#                                               Variety Style      Country  \
# 0                           T's Restaurant Tantanmen    Cup        Japan
# 1   Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack       Taiwan
# 2                       Cup Noodles Chicken Vegetable   Cup          USA
# 3                       GGE Ramen Snack Tomato Flavor  Pack       Taiwan
# 4                                     Singapore Curry  Pack        India
# ...

# %%
ramen_shape = ramen.shape
print("Number of observations: ", ramen_shape[0])
print("Number of columns: ", ramen_shape[1])
# Out:
# Number of observations:  2580
# Number of columns:  7

# %%
ramen.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2580 entries, 0 to 2579
# Data columns (total 7 columns):
# Review #    2580 non-null int64
# Brand       2580 non-null object
# Variety     2580 non-null object
# Style       2578 non-null object
# Country     2580 non-null object
# Stars       2580 non-null object
# Top Ten     41 non-null object
# dtypes: int64(1), object(6)
# memory usage: 141.2+ KB

# %%
ramen_stars = ramen.groupby('Stars')

# %%
 ramen_stars.first()
# Out:
#          Review #              Brand  \
# Stars
# 0            2527      Uni-President
# 0.1           128               Mama
# 0.25         2572         Ripe'n'Dry
# 0.5          2382           Nongshim
# 0.75         1920             Itsuki
# 0.9           535            Wai Wai
# 1            2579           Just Way
# 1.1           635             Ottogi
# 1.25         1669              A-One
# 1.5          2544             Lipton
# 1.75         2070   Tokushima Seifun
# 1.8            84            Samyang
# 2            2530             Ottogi
# 2.1           587           Sunlight
# 2.125         334             Nissin
# 2.25         2578             Nissin
# 2.3          2257               Fuku
# 2.5          2571               KOKA
# 2.75         2577            Wei Lih
# 2.8           127              Vifon
# 2.85          100      Unif / Tung-I
# 2.9           190              Maggi
# 3            2504           Nongshim
# 3.0          2044               Doll
# ...

# %%
# Summarise ramen data
ramen.describe(include='all')
# Out:
#            Review #   Brand Variety Style Country Stars Top Ten
# count   2580.000000    2580    2580  2578    2580  2580      41
# unique          NaN     355    2413     7      38    51      38
# top             NaN  Nissin    Beef  Pack   Japan     4      \n
# freq            NaN     381       7  1531     352   384       4
# mean    1290.500000     NaN     NaN   NaN     NaN   NaN     NaN
# std      744.926171     NaN     NaN   NaN     NaN   NaN     NaN
# min        1.000000     NaN     NaN   NaN     NaN   NaN     NaN
# 25%      645.750000     NaN     NaN   NaN     NaN   NaN     NaN
# 50%     1290.500000     NaN     NaN   NaN     NaN   NaN     NaN
# 75%     1935.250000     NaN     NaN   NaN     NaN   NaN     NaN
# max     2580.000000     NaN     NaN   NaN     NaN   NaN     NaN

# %% [markdown]
# * Review : unique numbers that inform the review order from the latest
# * Brand : Ramen brand
# * Variety: variation of ramen
# * Style : style of ramen
# * Country: Where the ramen is available
# * Stars : Ramen ratings
# * Top Ten: ramen achievement

# %%
ramen.isna().sum()
# Out:
# Review #       0
# Brand          0
# Variety        0
# Style          2
# Country        0
# Stars          0
# Top Ten     2539
# dtype: int64

# %%
ramen = ramen.dropna(subset=['Style'])
print(ramen["Style"].isna().sum())
# Out:
# 0

# %%
ramen['Style'].unique()
# Out:
# array(['Cup', 'Pack', 'Tray', 'Bowl', 'Box', 'Can', 'Bar'], dtype=object)

# %%
ramen['Style'].value_counts()
# Out:
# Pack    1531
# Bowl     481
# Cup      450
# Tray     108
# Box        6
# Can        1
# Bar        1
# Name: Style, dtype: int64

# %%
print(ramen["Country"].unique())
print(len(ramen["Country"].unique()), 'Countries')
# Out:
# ['Japan' 'Taiwan' 'USA' 'India' 'South Korea' 'Singapore' 'Thailand'
#  'Hong Kong' 'Vietnam' 'Ghana' 'Malaysia' 'Indonesia' 'China' 'Nigeria'
#  'Germany' 'Hungary' 'Mexico' 'Fiji' 'Australia' 'Pakistan' 'Bangladesh'
#  'Canada' 'Nepal' 'Brazil' 'UK' 'Myanmar' 'Netherlands' 'United States'
#  'Cambodia' 'Finland' 'Sarawak' 'Philippines' 'Sweden' 'Colombia'
#  'Estonia' 'Holland' 'Poland' 'Dubai']
# 38 Countries

# %%
ramen['Country'].value_counts()
# Out:
# Japan            352
# USA              323
# South Korea      309
# Taiwan           223
# Thailand         191
# China            168
# Malaysia         156
# Hong Kong        137
# Indonesia        126
# Singapore        109
# Vietnam          108
# UK                69
# Philippines       47
# Canada            41
# India             31
# Germany           27
# Mexico            25
# Australia         22
# Netherlands       15
# Nepal             14
# Myanmar           14
# Pakistan           9
# Hungary            9
# Bangladesh         7
# Colombia           6
# Brazil             5
# Cambodia           5
# Poland             4
# Fiji               4
# Holland            4
# Sarawak            3
# Dubai              3
# Finland            3
# Sweden             3
# Estonia            2
# Ghana              2
# Nigeria            1
# United States      1
# Name: Country, dtype: int64

# %%
top10 = ramen.dropna()
top10
# Out:
#       Review #             Brand  \
# 616       1964              MAMA
# 633       1947       Prima Taste
# 655       1925             Prima
# 673       1907       Prima Taste
# 752       1828     Tseng Noodles
# 891       1689      Wugudaochang
# 942       1638  A-Sha Dry Noodle
# 963       1617           MyKuali
# 995       1585            CarJEN
# 1059      1521          Maruchan
# 1072      1508             Mamee
# 1080      1500           MyKuali
# 1109      1471              Mama
# 1114      1466              Mama
# 1230      1350             Mamee
# 1250      1330   Sapporo Ichiban
# 1272      1308          Nongshim
# 1278      1302              Mama
# 1309      1271       Prima Taste
# 1382      1198     Samyang Foods
# 1397      1183             Paldo
# 1493      1087           MyKuali
# 1588       992       Prima Taste
# 1589       991       Prima Taste
# 1646       934          Nongshim
# 1670       910             Paldo
# 1757       823             Paldo
# ...

# %%
top10 = top10[top10['Top Ten'] != '\n'] #if the data in Top Ten column contains '\n'
top10 = top10.sort_values('Top Ten' ) #and we sort it by year
top10
# Out:
#       Review #             Brand  \
# 2475       105           Indomie
# 1972       608              Koka
# 2533        47           Indomie
# 2188       392            Nissin
# 2567        13   Sapporo Ichiban
# 2146       434         Mi Sedaap
# 2189       391             Myojo
# 2002       578          Nongshim
# 2295       285              Doll
# 1588       992       Prima Taste
# 1109      1471              Mama
# 1589       991       Prima Taste
# 1865       715           Indomie
# 1646       934          Nongshim
# 2549        31             Myojo
# 1757       823             Paldo
# 1493      1087           MyKuali
# 1278      1302              Mama
# 1250      1330   Sapporo Ichiban
# 1382      1198     Samyang Foods
# 1397      1183             Paldo
# 1230      1350             Mamee
# 1309      1271       Prima Taste
# 1272      1308          Nongshim
# 1080      1500           MyKuali
# 942       1638  A-Sha Dry Noodle
# 995       1585            CarJEN
# ...

# %%
ramen['Brand'].value_counts()[:10]
# Out:
# Nissin           381
# Nongshim          98
# Maruchan          76
# Mama              71
# Paldo             66
# Myojo             63
# Indomie           53
# Samyang Foods     52
# Ottogi            46
# Vina Acecook      34
# Name: Brand, dtype: int64

# %% [markdown]
# ## Data visualation

# %%
labels = 'Pack', 'Bowl', 'Cup' , 'Tray', 'Box' #We can't include 'Bar' and 'Can' because they only appear once in our data.
size = [1531, 481, 450, 108, 6]

f, ax = plt.subplots(1,1, figsize= (10,10))

ax.pie(size, labels = labels, autopct = '%1.2f%%', startangle = 180)
ax.axis('equal')
ax.set_title("Style", size = 20)

plt.show()

# %%
plt.figure(figsize = (10,120))
ramen.hist()
plt.suptitle("Histograms")
plt.show()

ramen.boxplot()
plt.title("Boxplot")
plt.show()
