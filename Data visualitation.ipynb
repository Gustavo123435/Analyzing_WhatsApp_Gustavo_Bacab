# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
df = pd.read_csv('UNdata_Export_20191125_111536572.csv')

# %%
df.head()
# Out:
#   Country or Area    Year(s) Variant  Value
# 0     Afghanistan  2010-2015  Medium  5.447
# 1     Afghanistan  2005-2010  Medium  6.478
# 2     Afghanistan  2000-2005  Medium  7.182
# 3     Afghanistan  1995-2000  Medium  7.654
# 4     Afghanistan  1990-1995  Medium  7.482

# %%
plt.figure(figsize=[10, 6], dpi = 150)

plt.plot('Year(s)', 'Value', data=df, markerfacecolor='blue', color='skyblue', marker = 'o', linestyle = 'dashed')
#plt.plot('x', 'y2', data=df, markerfacecolor='red', color='orangered', marker = 'x')
#plt.plot('x', 'y3', data=df, markerfacecolor='purple', color='lavender', marker  = 'd', label= "Foo")
#plt.legend()
plt.show()

# %%
data = pd.read_csv("train.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-2-8d21486d662e> in <module>
# ----> 1 data = pd.read_csv("train.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# ...

# %%
netflix = pd.read_csv("movie_titles.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-b140646e1887> in <module>
# ----> 1 netflix = pd.read_csv("movie_titles.csv")
#
# ~\Anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, doublequote, delim_whitespace, low_memory, memory_map, float_precision)
#     676                     skip_blank_lines=skip_blank_lines)
#     677
# ...

# %%
netflix
